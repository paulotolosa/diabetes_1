# %% [markdown]
# <a href="https://colab.research.google.com/github/paulotolosa/diabetes_1/blob/main/23_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8714e637-c6bd-45e3-894e-20b53ca5aa7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8714e637-c6bd-45e3-894e-20b53ca5aa7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Lee el archivo CSV cargado
data = pd.read_csv('diabetes.csv')

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
print(data.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el dataset
# Supongamos que el dataset se llama 'diabetes.csv'
data = pd.read_csv('diabetes.csv')

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(data['Glucose'], data['Outcome'], alpha=0.5)

# Agregar etiquetas y título
plt.title('Relación entre Glucosa y Riesgo de Diabetes')
plt.xlabel('Glucosa')
plt.ylabel('Riesgo de Diabetes')

# Mostrar la visualización
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar el estilo de los gráficos de Seaborn
sns.set_style("whitegrid")

# Crear un histograma con diferentes colores para representar las categorías de resultado
plt.figure(figsize=(10, 6))
sns.histplot(data, x='Glucose', hue='Outcome', kde=True, palette='husl', alpha=0.7)

# Agregar etiquetas y título
plt.title('Distribución de Glucosa por Resultado de Diabetes')
plt.xlabel('Glucosa')
plt.ylabel('Frecuencia')

# Mostrar la visualización
plt.legend(title='Resultado')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar el estilo de los gráficos de Seaborn
sns.set_style("whitegrid")

# Crear un diagrama de caja (boxplot) con un hue
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Outcome', y='BMI', hue='Outcome', palette='husl')

# Agregar título y etiquetas
plt.title('Relación entre BMI y Riesgo de Diabetes')
plt.xlabel('Resultado de Diabetes')
plt.ylabel('BMI')

# Mostrar la visualización
plt.legend(title='Resultado')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar el estilo de los gráficos de Seaborn
sns.set_style("whitegrid")

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Glucose', y='BMI', hue='Outcome', palette='husl', alpha=0.7)

# Agregar título y etiquetas
plt.title('Relación entre Glucosa, BMI y Diabetes')
plt.xlabel('Glucosa')
plt.ylabel('BMI')

# Mostrar la leyenda
plt.legend(title='Diabetes')

# Mostrar la visualización
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Crear una figura y un conjunto de ejes tridimensionales
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Extraer los datos para cada variable
glucose = data['Glucose']
bmi = data['BMI']
insulin = data['Insulin']
outcome = data['Outcome']

# Dibujar los puntos en el gráfico tridimensional, colores según el resultado de diabetes
ax.scatter(glucose[outcome==0], bmi[outcome==0], insulin[outcome==0], c='b', label='No Diabético', alpha=0.7)
ax.scatter(glucose[outcome==1], bmi[outcome==1], insulin[outcome==1], c='r', label='Diabético', alpha=0.7)

# Etiquetas de los ejes
ax.set_xlabel('Glucosa')
ax.set_ylabel('BMI')
ax.set_zlabel('Insulina')

# Título del gráfico
plt.title('Relación entre Glucosa, BMI, Insulina y Riesgo de Diabetes')

# Leyenda
plt.legend()

# Mostrar el gráfico
plt.show()
